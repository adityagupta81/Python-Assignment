# %% [markdown]
# # Assignment  Tasks

# %% [markdown]
# # Task -1 -->Import the data set into a Pandas DataFrame.

# %%
# Importing some functions 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Specify the file path 
csv_file = r'E:\Data\Assignment Data\Movie Assignment Data.csv'

# Read the Csv file into a Dataframe
df = pd.read_csv(csv_file)

df
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %% [markdown]
# # Task 2 -->Generate descriptive statistics for the budget of all the movies.

# %%
# Creating budget statistics of all the movies.
budget_stats = df['budget'].describe()

# Print the descriptive statistics report.
budget_stats
# Out:
# count    1.000000e+02
# mean     7.838400e+07
# std      7.445295e+07
# min      3.000000e+06
# 25%      1.575000e+07
# 50%      4.225000e+07
# 75%      1.500000e+08
# max      2.600000e+08
# Name: budget, dtype: float64

# %% [markdown]
# # Task 3 -->Find out how many of the top-rated movies produced in the United States have a PG-13 rating.

# %%
# Now filter the dataframe for the  top rated movies produced in US with PG-13 rating.
usa_topRated_movies = df [ (df['Country'] ==  'USA') & (df['content_rating'] == 'PG-13')]

# Print the top rated movies produced in US with PG-13 rating
usa_topRated_movies
# Out:
#                                          Title  title_year     budget  \
# 0                                   La La Land        2016   30000000
# 3                                      Arrival        2016   47000000
# 6                               Doctor Strange        2016  165000000
# 8                        The Dark Knight Rises        2012  250000000
# 9                   Captain America: Civil War        2016  250000000
# 10         The Hobbit: The Desolation of Smaug        2013  225000000
# 11                                The Avengers        2012  220000000
# 14                  X-Men: Days of Future Past        2014  200000000
# 15                     Star Trek Into Darkness        2013  190000000
# 16           The Hobbit: An Unexpected Journey        2012  180000000
# 17                            Edge of Tomorrow        2014  178000000
# 19                     Guardians of the Galaxy        2014  170000000
# ...

# %%
# Number of top rated movies in US with PG-13 rating
len(usa_topRated_movies)
# Out:
# 35

# %% [markdown]
# # Task 4-->Find out whether any of the top-rated movies produced in 2014 were not produced in the United States.

# %%
# Create a filter for movies that are produced in 2014.
movies_produced_2014 =  df[df['title_year'] == 2014 ]

# Now to find the movies which are not produced in the United States
non_US_movies = movies_produced_2014 [movies_produced_2014['Country'] != 'USA']

# Print the top rated non US movies produced in 2014
(non_US_movies)
# Out:
#                        Title  title_year    budget      Gross  \
# 45            The Lego Movie        2014  60000000  257756197
# 78  The Theory of Everything        2014  15000000   35887263
# 80                Ex Machina        2014  15000000   25440971
# 81        The Imitation Game        2014  14000000   91121452
#
#             actor_1_name   actor_2_name    actor_3_name  \
# 45        Morgan Freeman   Will Ferrell     Alison Brie
# 78        Eddie Redmayne   Emily Watson  Simon McBurney
# 80         Elina Alminas  Sonoya Mizuno   Corey Johnson
# 81  Benedict Cumberbatch   Rory Kinnear     Allen Leech
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 45                   11000                  8000.0                  2000.0
# 78                   13000                   876.0                   149.0
# 80                     149                   145.0                   123.0
# ...

# %% [markdown]
# # Task 5 -->Find the percentage of the top-rated movies that are in:
# 1 genre only ,
# 2 genres only ,
# 3 genres only

# %%
#  Find the number of top rated movies in genre 3 by using count function.
genre_3 = df.genre_3.count() 

# Calculate the percentage of the top rated movies.
genre_3 *100 / df.Title.count()
# Out:
# 74.0

# %%
#  Find the number of top rated movies in genre 2 by using count function.
genre_2 = df.genre_2.count() 

# Subtract the genre_3  from genre_2 to get the top rated movies which are not common.
genre2 = genre_2 - genre_3

# Calculate the percentage of the top rated movies.
genre2 *100 / df.Title.count()
# Out:
# 23.0

# %%
#  Find the number of top rated movies in genre 1 by using count function.
genre_1 = df.genre_1.count() 

# Subtract the genre_2  from genre_1 to get the top rated movies which are not common.
genre1 = genre_1 - genre_2

# Calculate the percentage of the top rated movies.
genre1 *100 / df.Title.count()
# Out:
# 3.0

# %% [markdown]
# # Task 6 --> Convert the budget and gross values from “dollars” to “dollars in millions” for all top-rated movies. Round the converted values down to 3 decimal places. For example, a value of 192,345,273 should be converted to 192.345.

# %%
# Create and filter the budget cols and round to 3 decimal place 
df["budget"] =np.round (df ['budget'] / 1000000,2)
df['budget']
# Out:
# 0      30.0
# 1     150.0
# 2      12.0
# 3      47.0
# 4       9.0
#       ...
# 95      3.3
# 96      3.0
# 97    245.0
# 98    150.0
# 99      5.0
# Name: budget, Length: 100, dtype: float64

# %%
# Create and filter the gross cols and round to 3 decimal place 
df["Gross"] =np.round (df ['Gross'] / 1000000,2)
df['Gross']
# Out:
# 0     151.10
# 1     341.27
# 2      51.74
# 3     100.55
# 4      47.70
#        ...
# 95     13.09
# 96      8.11
# 97    936.66
# 98    296.35
# 99      0.22
# Name: Gross, Length: 100, dtype: float64

# %%
# Display the dataframe.
df
# Out:
#                                            Title  title_year  budget   Gross  \
# 0                                     La La Land        2016    30.0  151.10
# 1                                       Zootopia        2016   150.0  341.27
# 2                                           Lion        2016    12.0   51.74
# 3                                        Arrival        2016    47.0  100.55
# 4                          Manchester by the Sea        2016     9.0   47.70
# ..                                           ...         ...     ...     ...
# 95                                      Whiplash        2014     3.3   13.09
# 96                               Before Midnight        2013     3.0    8.11
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0  936.66
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0  296.35
# 99                       Tucker and Dale vs Evil        2010     5.0    0.22
#
# ...

# %% [markdown]
# # Task 7 -->List all details for the top 10 movies with the highest profit, sorted from highest to lowest. Hint: Profit is not a column in the DataFrame. You will need to calculate it.

# %%
# Calculating profit by subtracting budget from gross cols.
df['Profit'] = df['Gross'] - df['budget']

# Display Profit cols.
df.head(10)
# Out:
#                         Title  title_year  budget   Gross  \
# 0                  La La Land        2016    30.0  151.10
# 1                    Zootopia        2016   150.0  341.27
# 2                        Lion        2016    12.0   51.74
# 3                     Arrival        2016    47.0  100.55
# 4       Manchester by the Sea        2016     9.0   47.70
# 5          Hell or High Water        2016    12.0   27.01
# 6              Doctor Strange        2016   165.0  232.64
# 7                     Tangled        2010   260.0  200.81
# 8       The Dark Knight Rises        2012   250.0  448.13
# 9  Captain America: Civil War        2016   250.0  407.20
#
#            actor_1_name        actor_2_name          actor_3_name  \
# 0          Ryan Gosling          Emma Stone            Amiée Conn
# 1      Ginnifer Goodwin       Jason Bateman            Idris Elba
# 2             Dev Patel       Nicole Kidman           Rooney Mara
# ...

# %%
# Sorting Values by profit and arrange them from highest to lowest.
df= df.sort_values (by='Profit', ascending = False)

# Display the details of top 10 movies with highest profit.
df.head(10)
# Out:
#                                          Title  title_year  budget   Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936.66
# 11                                The Avengers        2012   220.0  623.28
# 47                                    Deadpool        2016    58.0  363.02
# 32             The Hunger Games: Catching Fire        2013   130.0  424.65
# 12                                 Toy Story 3        2010   200.0  414.98
# 8                        The Dark Knight Rises        2012   250.0  448.13
# 45                              The Lego Movie        2014    60.0  257.76
# 1                                     Zootopia        2016   150.0  341.27
# 41                               Despicable Me        2010    69.0  251.50
# 18                                  Inside Out        2015   175.0  356.45
#
#          actor_1_name       actor_2_name           actor_3_name  \
# 97        Doug Walker         Rob Walker                      0
# ...

# %% [markdown]
# # Task 8 --> Generate a list of all the actors, in alphabetical order by the first name, that have starred in a top-rated movie. If an actor has starred in multiple movies, their name should appear only once on the list. Assume that all actors’ names are in the format <first_name> <last_name>.

# %%
# Collect  all the values of the cols of  actor_1_name, actor_2_name and  actor_3_name in a single series and called them as all_actors and sort them .

actor_1 = df['actor_1_name']
actor_2 = df['actor_2_name']
actor_3 = df['actor_3_name']

all_actors = actor_1.append(actor_2).append(actor_3).sort_values()

# Display  the name of all actors. 
all_actors
# Out:
# 97                  0
# 23    Abraham Benrubi
# 16         Adam Brown
# 10         Adam Brown
# 82        Aidan Quinn
#            ...
# 99       Tyler Labine
# 19         Vin Diesel
# 45       Will Ferrell
# 87         Will Forte
# 29       ZoÃ« Kravitz
# Length: 300, dtype: object

# %%
# Convert the series into a list after removing the duplicates from all actors name using unique function.
all_actor_list = list(all_actors.unique())
all_actor_list
# Out:
# ['0',
#  'Abraham Benrubi',
#  'Adam Brown',
#  'Aidan Quinn',
#  'Aidan Turner',
#  'Albert Brooks',
#  'Albert Finney',
#  'Aldis Hodge',
#  'Alexandra Maria Lara',
#  'Alfred Enoch',
#  'Alison Brie',
#  'Allen Leech',
#  'America Ferrera',
#  'Amiée Conn',
#  'Amy Adams',
#  'Amy Poehler',
#  'Amy Ryan',
#  'Amy Warren',
#  'Andrew Garfield',
#  'Anna Kendrick',
#  'Anne Hathaway',
#  'Ariane Labed',
#  'Athina Rachel Tsangari',
#  'Ato Essandoh',
#  'Audrey Fleurot',
#  'Basher Savage',
#  'Ben Foster',
#  'Benedict Cumberbatch',
#  'Benedict Wong',
#  'Bernardo Saracino',
#  'Beth Grant',
#  'Bill Murray',
#  'Billy Crudup',
#  'Bob Balaban',
#  'Brad Garrett',
#  'Brad Pitt',
#  'Bradley Cooper',
#  'Brian Johnson',
#  "Brian d'Arcy James",
#  'Bruce Dern',
#  'Bruce Green',
#  'Bruce Greenwood',
#  'Bruce Willis',
#  'Bryce Dallas Howard',
#  'BÃ©rÃ©nice Bejo',
#  'Casey Affleck',
#  'Charlie Talbert',
#  'Charlize Theron',
#  'Chelan Simmons',
#  'Chiwetel Ejiofor',
# ...

# %%
# Removing 0from the above list by using remove function.
all_actor_list.remove('0')
all_actor_list
# Out:
# ['Abraham Benrubi',
#  'Adam Brown',
#  'Aidan Quinn',
#  'Aidan Turner',
#  'Albert Brooks',
#  'Albert Finney',
#  'Aldis Hodge',
#  'Alexandra Maria Lara',
#  'Alfred Enoch',
#  'Alison Brie',
#  'Allen Leech',
#  'America Ferrera',
#  'Amiée Conn',
#  'Amy Adams',
#  'Amy Poehler',
#  'Amy Ryan',
#  'Amy Warren',
#  'Andrew Garfield',
#  'Anna Kendrick',
#  'Anne Hathaway',
#  'Ariane Labed',
#  'Athina Rachel Tsangari',
#  'Ato Essandoh',
#  'Audrey Fleurot',
#  'Basher Savage',
#  'Ben Foster',
#  'Benedict Cumberbatch',
#  'Benedict Wong',
#  'Bernardo Saracino',
#  'Beth Grant',
#  'Bill Murray',
#  'Billy Crudup',
#  'Bob Balaban',
#  'Brad Garrett',
#  'Brad Pitt',
#  'Bradley Cooper',
#  'Brian Johnson',
#  "Brian d'Arcy James",
#  'Bruce Dern',
#  'Bruce Green',
#  'Bruce Greenwood',
#  'Bruce Willis',
#  'Bryce Dallas Howard',
#  'BÃ©rÃ©nice Bejo',
#  'Casey Affleck',
#  'Charlie Talbert',
#  'Charlize Theron',
#  'Chelan Simmons',
#  'Chiwetel Ejiofor',
# ...

# %% [markdown]
# # Task 9 --> The movie studio wants to determine who it should approach to act in its next movie production. Find the top 3 actors who appeared in the most top-rated movies.

# %%
# Create a list  of  actors name from the top rated movies.
actors = actor_1.append(actor_2).append(actor_3).sort_values()

# Counting the number of times the actor appeared.
actors.value_counts().head()

# Display the name of top 3 actors.
actors.value_counts().head(3)
# Out:
# Leonardo DiCaprio     5
# Tom Hardy             5
# Scarlett Johansson    4
# dtype: int64

# %% [markdown]
# # Task 10 -->Create a data visualization that shows each country and the number of top-rated movies produced in it. Find the country that produced the most top-rated movies.

# %%
# Creating a data visualization by group and sorting them by Title.
Data_visua_df = df.groupby(['Country']).count()[['Title']].sort_values(by='Title', ascending = False)

# Display the Country and Title.
Data_visua_df
# Out:
#            Title
# Country
# USA           81
# UK            11
# Australia      3
# France         3
# Canada         1
# Spain          1

# %%
# Creating a bar plot for the above data.
Data_visua_df.plot(kind ='bar')
plt.xlabel("Country")
plt.ylabel("Count")
plt.show()

# Find the Country with the most top Rated movies .
Top_rated_country = Data_visua_df.idxmax()
print(f"Country with the most Top Rated movies is {Top_rated_country[0]} with {Data_visua_df['Title'].max()} movies.")
# Out:
# Country with the most Top Rated movies is USA with 81 movies.
